# %%
from dotenv import load_dotenv

load_dotenv()

from custom_gmail_reader import CustomGmailReader

# Instantiate the CustomGmailReader

loader = CustomGmailReader(
    query="",
    max_results=50,
    results_per_page=10,
    service=None
)

documents = loader.load_data()

# %%
from llama_index.core import Settings
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler
 
langfuse_callback_handler = LlamaIndexCallbackHandler()
Settings.callback_manager = CallbackManager([langfuse_callback_handler])

# %%
# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:20]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: aruneshm@gmail.com
# From: Uber <uber@uber.com>
# Subject: Want up to 50% off? Skip the store run. 🤩
# Date: Fri, 20 Sep 2024 02:54:18 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 2:
# To: aruneshm@gmail.com
# From: "Generative AI on AWS (San Francisco, Global)" <info@email.meetup.com>
# Subject: 📅 Wednesday: Join 13 Generative AI on AWS Experts at "AWS Loft Event: GenAI Night for Students and Newbies (Hands-On Workshop!)"
# Date: Fri, 20 Sep 2024 02:42:19 +0000 (UTC)
# Content snippet:
#
# Generative AI on AWS (San Francisco, Global)
# invites you to keep connecting
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Meetup
#
#
#
#
#
#
#
#
#
#
#              Hide ads
# ( http://clicks.meetup.com/ls/click?upn=u001.NY3oBFzZ5LJDG7YcnfSAKsQAD0GnFi1zzMJ-2FAp8-2FvJUkMM-2Br2f-2FxE-2F8L-2F-2BsJ9kFU9uEEGVlNlru9LfLkKTapJQQgtB13IyilvAA8Yjea1TOxm7C3gIG-2FhTLIfNOjbJWzVX9PinpaWi5AACc1yzCScvX4fYk8JoYnDKakzb9-2BZ1H6huXpgqQ5YPnfumH48ZjY-2FgGpfC7KFFHKYhKpyZB1cspp-2Bw0QJqYGaDgxNlEHR9RG7lfvhES1axhnmIjxs2f-2F5zvtMTto3M8G-2FuOMcl-2FK0Q-3D-3D1ycQ_5ZawQ6x7vUQNmZXflQrpWHbhvRyqixKlg4VzKEUDtmgKi4pN1iDitosvU-2BgFZKoV-2BpUGPccq63Vx3P19kMzrn-2FByRxi5iGDrCHLR0YHRR95hC1ZXYQDR9JJDgwIyqB1dcZz0LfD5WcM-2F6hafcYnRg7kwLM-2FmJCjcOwAeDHnAJhFxH1yolp7zUURcMHNnoIIpcUD9fKJZhpTCKdD0OY4UUNIKkg4E-2BezWR5vJ7TR74aecWaL8hfO9yoQXR4nOunur3ISA6jXGso9GC7U4yaMlog3bF68GF2hdWt8xrZvoBZEc4S0zMvAyiBDV6kq9MQlzFH2mYzfMAGaBiFmq-2FTpAJGM9ZlzoLXQsNLGN4YpEQT1Lp5Rq6NNx...
HR9RG7lfvhES1axhnmIjxs2f-2F5zvtMTto3M8G-2FuOMcl-2FK0Q-3D-3D38jI_5ZawQ6x7vUQNmZXflQrpWHbhvRyqixKlg4VzKEUDtmgKi4pN1iDitosvU-2BgFZKoV-2BpUGPccq63Vx3P19kMzrn2n1sH4aSRR7UXP4HhshD-2FtjWi6ONlo39RkdAwMgxI7OVwjAqwkibHT-2FczufHlhFcCo-2FvmVH-2FK71lXFb7Qx3CW0KA0-2BJKP3YMX4hmRde3c5a-2F9XYgT1YcunM9mYt5Xk3On6lvGSi67iVxTX5F4-2BrF8NmkClhD6aPW-2Bp9b2Qw5YjZseergx9OdCF9t0yg60F29ulVwg081KlqM9Uq1NdY9DpIa1Erti8DA91ngc4-2BvCgcjPfr2DzavhcvmzuQy7wm0PlNbpFt7l2FTVdSe5juuXuoeA-2Fqcjb1WLcK1tTO69HAIQSGjS8...
# ==================================================
# Document 5:
# To: aruneshm@gmail.com
# From: Wellfound <newsletters@hi.wellfound.com>
# Subject: Office mandates a boon for startups
# Date: Fri, 20 Sep 2024 01:02:18 +0000
# Content snippet: Amazon floods tech talent pool with RTO mandates, startups buy startups,
# Estonia digs deeptech, fusion attracts billions, 10 hot startups hiring in
# Amazon’s backyard, plus 5 trending startups hiring this week.
#
#
#
#
#  <https://wellfound.com>
# view entire message
# <https://links.wellfound.com/e/evib?_t=26b4e8aeb47d4cd3acd5eba415f76f62&_m=52e2c8d159c6421fb456d0290411a128&_e=pxuBzuMi1b9MJ96fjI03erBbWO5z7lArAprKH8ub4rlPrslYLZDAi5eieh2jDVhE>
#
#
#  <>
#
#
#  <https://wellfound.com/jobs>
#
#
#
# Quick Hits
#
#
# ‘Bharat’ boom: Rural India
# <https://inc42.com/buzz/accel-rolls-out-fourth-cohort-of-its-pre-seed-programme-with-focus-on-ai-fintech-ecommerce/>
#  rises.
#
# Beijing bust: China
# <https://www.ft.com/content/1e9e7544-974c-4662-a901-d30c4ab56eb7> venture dips.
#
# Big Insight: Fund nears $10B
# <https://techcrunch.com/2024/09/15/insight-partners-is-closing-in-on-a-whopping-10b-new-fund/>
# .
#
# Blue skies: Social app hits 10M
# <https://techcrunch.com/2024/09/16/bluesky-now-has-10-million-users/>.
#
# Cisco cuts: Tech...
# ==================================================
# Document 6:
# To: aruneshm@gmail.com
# From: Outerbounds Team <hello@outerbounds.co>
# Subject: 🚀 Unlock the Future of ML/AI: Exciting New Features & Highlights from Outerbounds Launch Week
# Date: Thu, 19 Sep 2024 20:35:38 -0400
# Content snippet: Discover the latest Outerbounds features designed to accelerate your ML/AI workflows. From powerful new deployment tools to real customer success stories, this week is packed with exciting updates!
#
# Hi Arunesh,
# Welcome to Langfuse! I'm Marc, one of the founders and here to help in case you have any questions.
#
# Some resources to get you started
#  * Quickstart [https://langfuse.com/docs/get-started] - all the information you need to get set up in one place
#
#  * Detailed integration docs [https://langfuse.com/docs/integrations/overview] (Python&JS SDKs, OpenAI, LangChain, LlamaIndex,
#    API, …)
#
#  * Introduction to tracing [https://langfuse.com/docs/tracing/overview] and its data model in Langfuse
#
#  * Check out the interactive demo [https://langfuse.com/demo] (you have access in your Langfuse account) and play with the chatbot
#    to see your traces in Langfuse
#
#
# If you have ideas regarding the project, share them with the community on Github Discussions [https://langfuse.com/ideas] or just
# reply to this email!
# Also, if you run into issues during setup, reach out to me or create a support thread [https://langfuse.com/gh-support] on GitHub.
#
# Best,
# Marc
#
# PS: Wha...
# ==================================================
# Document 11:
# To: Arunesh <aruneshm@gmail.com>
# From: GitHub <noreply@github.com>
# Subject: [GitHub] A third-party OAuth application has been added to your account
# Date: Thu, 19 Sep 2024 16:40:20 -0700
# Content snippet: Hey arunesh!
#
# A third-party OAuth application (Langfuse [US]) with read:user and user:email scopes was recently authorized to access your account.
# Visit https://github.com/settings/connections/applications/edbcaf30e5c4235e169f for more information.
#
# To see this and other security events for your account, visit https://github.com/settings/security-log
#
# If you run into problems, please contact support by visiting https://github.com/contact
#
# Thanks,
# The GitHub Team
#
# ...
# ==================================================
# Document 12:
# To: aruneshm@gmail.com
# From: Anand Sanwal <anand.sanwal@cbinsights.com>
# Subject: OpenAI vs. Google
# Date: Thu, 19 Sep 2024 19:23:18 -0400
# Content snippet: $ale$force.
#
# Easy (like Sunday morning).
#
# ROYGBIV jump scare.
#
# View in browser (https://research.cbinsights.com/e3t/Ctc/T5+113/c4SYk04/VVvzDh6KFWHFW2SmQxW79Lj5dW50jS-p5l90CCN8_nRFF5m_5PW69t95C6lZ3pCW5LXxPt4BvqdNW1D29c16pb6CfW20QJBW4vrHcQW5Nkrv08cdWYHW4sGFJF2wF0czW6PrZ6-1cjNz4W60C3Tj60CMgpW6nKFLg7DXDtMW1sT7_c44pNt1N4TzKczHYNffW1s9tyw5gL93nN5DcX0XW3wMMW8zbKsq4V56vDN36JznLfX-WVW7v6Ff51-xc7pW3dknzS8pfRgnW1c-l1-3SwLm7W38hYcL8M95tLW1D5THs6QKwKxW6wdgBl4T76vzW14m3Dp5gb4SjW2y53yP3Y-X8MW3c7VSW1RpyGBW32wH4V8sSZl1VWcF0c7_MTxtW14WDPx94T4t2W6WbYmm8h-L_LW5Np5k23rLhxGVP59Gm37BkcWW2FghB44w4xsKW470CwM6pKdQFW3SyBG35qX3yRN5-R41vbG7b7W6XH85l2kg9w3W4yQzkP8JqKQMW3DGbc65QF7zdf77NZ5z04 )
#
# September 19, 2024
#
# New fund, who dis?
#
# Hi there,
#
# Here is this week’s Hot or Not.
#
# Hot: AI funds
#
# Salesforce Ventures announced a new $500M AI fund this week.
#
# Just one year ago, it expanded the fund from $250M to $500M.
#
# Salesforce Ventures is a key source for the company’s M&A pipeline.
#
# Four of Sal...
# ==================================================
# Document 13:
# To: "aruneshm@gmail.com" <aruneshm@gmail.com>
# From: TWiST Ticker <thisweekinstartups@mail.beehiiv.com>
# Subject: More AI video generators are popping up
# Date: Thu, 19 Sep 2024 23:22:14 +0000 (UTC)
# Content snippet: ### **Top News**
#
# * **[Amazon releases a video generator](https://techcrunch.com/2024/09/19/amazon-releases-a-video-generator-but-only-for-ads/)**: Amazon has introduced an AI-powered video generator for advertisers that turns a product image into promotional short-form videos. The generator is currently in beta for select U.S. advertisers. After Runway’s [deal](https://www.wsj.com/business/media/lionsgate-studio-behind-john-wick-signs-deal-with-ai-startup-runway-f2180245?st=Xo3FPn&reflink=desktopwebshare_permalink) with Lionsgate yesterday and YouTube’s [partnership](https://techcrunch.com/2024/09/18/youtube-shorts-to-integrate-veo-google-ai-video-model/) with Google’s Veo, we should expect to see more AI video generation pop up.
#
# * **[Microsoft teams up with Anduril](https://www.bloomberg.com/news/articles/2024-09-19/microsoft-teams-with-startup-anduril-on-army-combat-goggle-system)**: The Peter Thiel-backed defense startup is partnering with Microsoft to enhance the U.S. Army's ...
# ==================================================
# Document 14:
# To: aruneshm@gmail.com
# From: The New York Times <nytimes@e.newyorktimes.com>
# Subject: Ends soon: Best-offer sale: $1/wk.
# Date: Thu, 19 Sep 2024 23:06:02 +0000
# Content snippet: Enjoy the complete Times experience with a full year of savings on news, culture, sports and more.
#
# -----------------------------------------------------------------
#
# -- The New York Times --
#
# -----------------------------------------------------------------
#
# 365 Days of Discovery. One year of savings.
#
# -----------------------------------------------------------------
#
# Click here to view email with images:
#  https://e.newyorktimes.com/pub/sf/FormLink?_ri_=X0Gzc2X%3DAQjkPkSUAQG0vJs4FkumSmm0d8C9AMWe0gzfzeMMRRzazeucnReKzaXWzf882zazejNzaBLON1IYmMu7DsmgnVXMtX%3DAQjkPkSUAQGyFzdjvIUqaG0hs04lzaROkWcOgeEktAJjK3qDyRdX1HnlszaYzfN7R1K95oIMzg5zcq0AUR&_ei_=EUlaGGF4SNMvxFF7KucKuWNzJfX_3M2kuxPe_XLrrfS62Hi-zJlD1tELUoXzsrQ40x8Dt7iZHiqt.&_di_=rf30e9dc2trrpklscd9e1v76pumnjkrvumo1feldbgmc3ge6tfo0Jg%3D%3D
#
# -----------------------------------------------------------------
#
# This email was sent to aruneshm@gmail.com
#
# To stop receiving updates and offers from The Times, including those regard...
# ==================================================
# Document 15:
# To: aruneshm@gmail.com
# From: Santa Clara City Library <librarians@info.santaclaraca.gov>
# Subject: COMIC CON: Crafts & Volunteer Opportunities for Santa Clara City Library Comic Con 2024!
# Date: Thu, 19 Sep 2024 23:02:56 +0000
# Content snippet:
#
#
#
#
# Santa Clara City Library Comic Con 2024 Banner [ https://www.SCLibrary.org/Comic-Con ]
#
#
#
#
# *Comic Con News & Updates *
#
#
#
#
#
#
# Craft Collage 2 [ https://www.sclibrary.org/calendar/events/comic-con/panels-activities#Crafts ]
#
# Announcing Crafts and Volunteer Opportunities for Santa Clara City Library Comic Con 2024!
#
# Santa Clara City Library Comic Con 2024 is just around the corner on *October 12*! On top of all the panels, activities, and special guests [ https://www.sclibrary.org/calendar/events/comic-con/panels-activities ] you'll see, you'll also have the chance to get hands-on and take a little slice of Comic Con home with you by making your own crafts. We also have volunteer opportunities [ https://forms.office.com/g/kG3xawhRGX ] available for ages 14 and up. RSVP [ https://www.eventbrite.com/e/santa-clara-city-library-comic-con-tickets-907008545977?aff=oddtdtcreator ] for Comic Con today!
#
# ____________________________________________________...
# ==================================================
# Document 16:
# To: aruneshm@gmail.com
# From: JJ Alerts <alerts@johnsonjobs.com>
# Subject: Jobs at Stratodesk Corp, Walmart and Verkada
# Date: Thu, 19 Sep 2024 22:35:48 +0000
# Content snippet: ...
# ==================================================
# Document 17:
# To: "aruneshm@gmail.com" <aruneshm@gmail.com>
# From: AllClear ID <noreply@protect.allclearid.com>
# Subject: Your monthly activity summary is ready to review
# Date: Thu, 19 Sep 2024 17:34:51 -0500 (CDT)
# Content snippet: ...
# ==================================================
# Document 18:
# To: aruneshm@gmail.com
# From: Google <no-reply@accounts.google.com>
# Subject: Security alert for arunesh.tech@gmail.com
# Date: Thu, 19 Sep 2024 22:26:11 GMT
# Content snippet: This is a copy of a security alert sent to arunesh.tech@gmail.com.
# aruneshm@gmail.com is the recovery email for this account. If you don't
# recognize this account, remove
# <https://accounts.google.com/AccountDisavow?adt=AOX8kiqWzzPbrZNSR_yAUSKjZkhXdROmteTqRnpfaYORf6nzZCJugmLAQ1_30GY&rfn=325>
# it.
# [image: Google]
# A new sign-in on Mac
#
#
# arunesh.tech@gmail.com
# We noticed a new sign-in to your Google Account on a Mac device. If this
# was you, you don’t need to do anything. If not, we’ll help you secure your
# account.
# Check activity
# <https://accounts.google.com/AccountChooser?Email=arunesh.tech@gmail.com&continue=https://myaccount.google.com/alert/nt/1726784771000?rfn%3D325%26rfnc%3D1%26eid%3D-2888524105587898303%26et%3D1>
# You can also see security activity at
# https://myaccount.google.com/notifications
# You received this email to let you know about important changes to your
# Google Account and services.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
# ...
# ==================================================
# Document 19:
# To: aruneshm@gmail.com
# From: Google <no-reply@accounts.google.com>
# Subject: Security alert for arunesh.tech@gmail.com
# Date: Thu, 19 Sep 2024 22:26:08 GMT
# Content snippet: This is a copy of a security alert sent to arunesh.tech@gmail.com.
# aruneshm@gmail.com is the recovery email for this account. If you don't
# recognize this account, remove
# <https://accounts.google.com/AccountDisavow?adt=AOX8kiqzNMMoSWY7t6Ne27fGmBR8vJDS59UJColl1jzHgwnGOEncpWtZAwt1z_M&rfn=364>
# it.
# [image: Google]
# New passkey added to your account
#
#
# arunesh.tech@gmail.com
# If you didn’t add a passkey, someone might be using your account. Check and
# secure your account now.
# Check activity
# <https://accounts.google.com/AccountChooser?Email=arunesh.tech@gmail.com&continue=https://myaccount.google.com/alert/nt/1726784768486?rfn%3D364%26rfnc%3D1%26eid%3D1815924177288693485%26et%3D1>
# You can also see security activity at
# https://myaccount.google.com/notifications
# You received this email to let you know about important changes to your
# Google Account and services.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
# ...
# ==================================================
# Document 20:
# To: aruneshm@gmail.com
# From: Capital One <capitalone@message.capitalone.com>
# Subject: Pending: Enroll by September 26, 2024 to get 0% APR on purchases for 6 months
# Date: Thu, 19 Sep 2024 22:15:15 +0000
# Content snippet: Enrollment required for your lower APR on purchases with your Quicksilver Credit Card.
# --
# [
# [Sign in to your account]
# [Sign in to your account]
# ](https://click-message.capitalone.com/f/a/j6fNpzZat_SsS_lASMwUFQ~~/AAAAAQA~/RgRozydzP0R1aHR0cDovL21pLmNhcGl0YWxvbmUuY29tL3AvY3AvZjZmNDRhMmZkYjgyMGNmOS9jP3VybD1odHRwJTNBJTJGJTJGbWkuY2FwaXRhbG9uZS5jb20lMkZwJTJGcnAlMkZiMGU2OTAzZWRhMWY2OGIxJTJGdXJsVwZjYXBvbmVCCmbdc6LsZk5LuQVSEmFydW5lc2htQGdtYWlsLmNvbVgEAAAAAA~~)
# [Sign in](https://click-message.capitalone.com/f/a/j6fNpzZat_SsS_lASMwUFQ~~/AAAAAQA~/RgRozydzP0R1aHR0cDovL21pLmNhcGl0YWxvbmUuY29tL3AvY3AvZjZmNDRhMmZkYjgyMGNmOS9jP3VybD1odHRwJTNBJTJGJTJGbWkuY2FwaXRhbG9uZS5jb20lMkZwJTJGcnAlMkZiMGU2OTAzZWRhMWY2OGIxJTJGdXJsVwZjYXBvbmVCCmbdc6LsZk5LuQVSEmFydW5lc2htQGdtYWlsLmNvbVgEAAAAAA~~)
# [
# [Capital One]
# [Capital One]
# ](https://click-message.capitalone.com/f/a/Mr08-ut9Ar21k2Xdx9Fk7g~~/AAAAAQA~/RgRozydzP0QbaHR0cHM6Ly93d3cuY2FwaXRhbG9uZS5jb20vVwZjYXBvbmVCCmbdc6LsZk5LuQVSEmFydW5lc2htQGdtYWlsLmNvbVgEAAAAAA~~)
# []
# []...
# ==================================================

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
response = query_engine.query("What is the latest offer from CapitalOne ?")
print(response)
# Out:
# Item exceeds size limit (size: 2182357), dropping input / output / metadata of item until it fits.
# The latest offer from Capital One is to enroll by September 26, 2024, to get 0% APR on purchases for 6 months.
